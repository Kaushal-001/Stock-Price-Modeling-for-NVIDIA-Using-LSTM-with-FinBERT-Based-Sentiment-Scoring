# %% [markdown]
# ##Collecting data for the stock market using yfinance

# %% [markdown]
# ###connecting to the google collab server
#
# 1.
# pip install jupyter_http_over_ws
# jupyter serverextension enable --py jupyter_http_over_ws
#
# 2.
# jupyter notebook \
# --NotebookApp.allow_origin='https://colab.research.google.com' \
# --port=8888 \
# --NotebookApp.port_retries=0
#
# 3. select the url and connect it to the google colab in browser

# %%
import pandas as pd
import yfinance as yf

# %%
ticker = "NVDA"
start_date = "2020-01-01"
end_date = "2025-09-30"

# %% [markdown]
# ## DATA COLLECTION AND SCRAPING FOR APPLE COMPANY

# %%
stock_data = yf.download(ticker, start=start_date, end=end_date)
# Out:
# /var/folders/1g/z59fmhb54sgcqt0rx08xnfyr0000gn/T/ipykernel_99803/2580080722.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stock_data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
print(stock_data.tail())
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            NVDA        NVDA        NVDA        NVDA       NVDA
# Date
# 2025-09-23  178.429993  182.419998  176.210007  181.970001  192559600
# 2025-09-24  176.970001  179.779999  175.399994  179.770004  143564100
# 2025-09-25  177.690002  180.259995  173.130005  174.479996  191586700
# 2025-09-26  178.190002  179.770004  174.929993  178.169998  148573700
# 2025-09-29  181.850006  184.000000  180.320007  180.429993  193063500

# %%
stock_data.shape
# Out:
# (1443, 5)

# %% [markdown]
# ## Imports all the library for Stock prediciton of NVIDIA using LSTM

# %%
#from tensorflow import keras
import pandas as pd
import numpy as np
import seaborn as sns
import os
from datetime import datetime
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
#from tensorflow import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow as tf
#       2 #from tensorflow import keras
#
# File ~/Desktop/Stock prediction & sentiment analysis/.venv/lib/python3.11/site-packages/tensorflow/__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# File ~/Desktop/Stock prediction & sentiment analysis/.venv/lib/python3.11/site-packages/tensorflow/python/pywrap_tensorflow.py:32
#      29   print(f'{traceback.format_exc()}')
# ...

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' #Tensorflow will throw some warnings while we code. so to suppress those warning we are using this code.

# %%
import tensorflow as tf

# %%
import yfinance as yf

ticker = "NVDA"
start_date = '2020-01-01'
end_date = '2025-11-03'

# %%
data = yf.download(ticker, start=start_date, end=end_date)
# Out:
# /var/folders/1g/z59fmhb54sgcqt0rx08xnfyr0000gn/T/ipykernel_43390/3223770355.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
data.to_csv("/Users/kaushaljha/Desktop/Stock prediction & sentiment analysis/news_data/nvidia_stock.csv")
